# %%
#SCATTER PLOT
people = ['kiran','arun','vijay','varun']
age =[25, 30, 35, 40, 45]
height =[145, 151, 165, 173]
weight=[45, 55, 65, 75]
import matplotlib.pyplot as plt
plt.scatter(weight,height)
plt.title("RELATIONSHIP B/W WEIGHT AND HEIGHT")
plt.ylabel("height in meters")
plt.xlabel("weight in kgs")
plt.show()

# %%
#BAR PLOT
people = ['kiran','arun','vijay','varun']
age =[25, 30, 35, 40, 45]
height =[145, 151, 165, 173]
weight=[45, 55, 65, 75]
import matplotlib.pyplot as plt
plt.bar(people,weight)
plt.title("BAR PLOT")
plt.ylabel("weight in kgs")
plt.xlabel("name")
plt.show()

# %%
# HISTOGRAM
people = ['kiran','arun','vijay','varun']
age =[25, 30, 35, 40, 45]
height =[145, 151, 165, 173]
weight=[45, 55, 65, 75]
import matplotlib.pyplot as plt
plt.hist(weight)
plt.title("HISTOGRAM")
plt.xlabel("weight in kgs")
plt.show()

# %%
# !pip install openpyxl
# Out:
# ...
#      -------------------------------------- 250.0/250.0 kB 1.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

data_excel = pd.read_csv("C:/Users/Sriman Reddy/OneDrive/Desktop/AIML datasets/DATASET1.csv")

data_csv = pd.read_csv("C:/Users/Sriman Reddy/OneDrive/Desktop/AIML datasets/DATASET2.csv.tsv",sep='\t')

data_tsv = pd.read_excel("C:/Users/Sriman Reddy/OneDrive/Desktop/AIML datasets/DATASET3.xlsx")

print(data_excel)

print(data_csv)

print(data_tsv)
# Out:
#             Name   Age        Ht no      Place  Unnamed: 4  Unnamed: 5
# 0       RajaRohan    19  2203A52126  Huzurabad         NaN         NaN
# 1  Vamshi krishna    19  2203A52127     Ambala         NaN         NaN
# 2         Avinash    19  2203A52227   Indurthi         NaN         NaN
# 3    Gopi krishna    21  2203A52076     Parkal         NaN         NaN
# 4          Sravan    19  2203A52099   Warangal         NaN         NaN
#             Name   Age        Ht no      Place  Unnamed: 4  Unnamed: 5
# 0       RajaRohan    19  2203A52126  Huzurabad         NaN         NaN
# 1  Vamshi krishna    19  2203A52127     Ambala         NaN         NaN
# 2         Avinash    19  2203A52227   Indurthi         NaN         NaN
# 3    Gopi krishna    21  2203A52076     Parkal         NaN         NaN
# 4          Sravan    19  2203A52099   Warangal         NaN         NaN
#           Table 1 Unnamed: 1  Unnamed: 2 Unnamed: 3
# 0           Name        Age        Ht no      Place
# ...

# %%
graph1 = {
    'A' : ['B','S'],
    'B' : ['A'],
    'C' : ['D','E','F','S'],
    'D' : ['C'],
    'E' : ['C','H'],
    'F' : ['C','G'],
    'G' : ['F','S'],
    'H' : ['E','G'],
    'S' : ['A','C','G']
}
 
def dfs(graph, node, visited):
    if node not in visited:
        visited.append(node)
        for k in graph[node]:
            dfs(graph,k, visited)
    return visited
 
visited = dfs(graph1,'D', [])
print(visited)
# Out:
# ['D', 'C', 'E', 'H', 'G', 'F', 'S', 'A', 'B']
